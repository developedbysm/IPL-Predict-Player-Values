# %% [markdown]
# # <center>Predict IPL Player Value

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Reading the IPL data of the year 2008

# %%
ipl_08=pd.read_csv("2008.csv")
ipl_08.head()
# Out:
#    Rank         Player              Team  RAA   Wins  EFscore    Salary  \
# 0     1       SE Marsh   Kings XI Punjab  377  1.355    0.231       NaN
# 1     2      SR Watson  Rajasthan Royals  347  1.250    0.297  $125,000
# 2     3  Sohail Tanvir  Rajasthan Royals  294  1.059    0.194       NaN
# 3     4      G Gambhir  Delhi Daredevils  216  0.776    0.160  $725,000
# 4     5       GC Smith  Rajasthan Royals  202  0.725    0.139  $250,000
#
#         Value
# 0  $1,270,355
# 1  $1,209,660
# 2  $1,099,252
# 3    $935,664
# 4    $906,183

# %% [markdown]
# ### Reading the IPL data of the year 2009

# %%
ipl_09=pd.read_csv("2009.csv")
ipl_09.head()
# Out:
#    Rank          Player                   Team  RAA   Wins  EFscore    Salary  \
# 0     1       ML Hayden    Chennai Super Kings  338  1.366    0.238  $375,000
# 1     2  AB de Villiers       Delhi Daredevils  256  1.037    0.195  $300,000
# 2     3       JP Duminy         Mumbai Indians  191  0.775    0.177  $950,000
# 3     4        BJ Hodge  Kolkata Knight Riders  189  0.766    0.196       NaN
# 4     5       RG Sharma        Deccan Chargers  156  0.630    0.174  $750,000
#
#         Value
# 0  $1,331,596
# 1  $1,145,098
# 2    $996,579
# 3    $991,477
# 4    $914,384

# %% [markdown]
# ### Reading the IPL data of the year 2010

# %%
ipl_10=pd.read_csv("2010.csv")
ipl_10.head()
# Out:
#    Rank            Player                         Team  RAA   Wins  EFscore  \
# 0     1      SR Tendulkar               Mumbai Indians  268  0.948    0.205
# 1     2          SK Raina          Chennai Super Kings  239  0.845    0.223
# 2     3  DPMD Jayawardene              Kings XI Punjab  195  0.691    0.146
# 3     4      KP Pietersen  Royal Challengers Bangalore  160  0.566    0.126
# 4     5         JH Kallis  Royal Challengers Bangalore  157  0.556    0.268
#
#        Salary       Value
# 0         NaN  $1,047,446
# 1    $650,000    $990,667
# 2    $475,000    $905,775
# 3  $1,550,000    $836,869
# 4    $900,000    $831,356

# %% [markdown]
# ### Reading the IPL data of the year 2011

# %%
ipl_11=pd.read_csv("2011.csv")
ipl_11.head()
# Out:
#    Rank        Player                         Team  RAA   Wins  EFscore  \
# 0     1      CH Gayle  Royal Challengers Bangalore  351  1.303    0.239
# 1     2    SL Malinga               Mumbai Indians  325  1.207    0.207
# 2     3   S Badrinath          Chennai Super Kings  267  0.990    0.160
# 3     4      SE Marsh              Kings XI Punjab  246  0.912    0.149
# 4     5  SR Tendulkar               Mumbai Indians  217  0.807    0.166
#
#      Salary       Value
# 0  $650,000  $1,674,414
# 1       NaN  $1,592,801
# 2  $800,000  $1,408,322
# 3  $400,000  $1,342,011
# 4       NaN  $1,252,747

# %% [markdown]
# ### Reading the IPL data of the year 2012

# %%
ipl_12=pd.read_csv("2012.csv")
ipl_12.head()
# Out:
#    Rank     Player                         Team  RAA   Wins  EFscore  \
# 0     1   CH Gayle  Royal Challengers Bangalore  354  1.286    0.212
# 1     2   S Dhawan              Deccan Chargers  304  1.103    0.208
# 2     3  SP Narine        Kolkata Knight Riders  298  1.082    0.187
# 3     4  G Gambhir        Kolkata Knight Riders  221  0.804    0.148
# 4     5  AM Rahane             Rajasthan Royals  217  0.787    0.156
#
#        Salary       Value
# 0    $650,000  $1,644,515
# 1    $300,000  $1,500,824
# 2    $700,000  $1,484,335
# 3  $2,400,000  $1,266,050
# 4         NaN  $1,252,702

# %% [markdown]
# ### Reading the IPL data of the year 2013

# %%
ipl_13=pd.read_csv("2013.csv")
ipl_13.head()
# Out:
#    Rank      Player                         Team  RAA   Wins  EFscore  \
# 0     1    CH Gayle  Royal Challengers Bangalore  447  1.729    0.210
# 1     2  MEK Hussey          Chennai Super Kings  414  1.602    0.224
# 2     3     V Kohli  Royal Challengers Bangalore  339  1.311    0.179
# 3     4    DJ Bravo          Chennai Super Kings  258  1.001    0.218
# 4     5    SK Raina          Chennai Super Kings  253  0.981    0.143
#
#        Salary       Value
# 0  $2,000,000  $2,554,267
# 1    $425,000  $2,419,187
# 2  $1,800,000  $2,109,674
# 3    $200,000  $1,779,953
# 4  $1,300,000  $1,758,680

# %% [markdown]
# ### Reading the IPL data of the year 2014

# %%
ipl_14=pd.read_csv("2014.csv")
ipl_14.head()
# Out:
#    Rank      Player                         Team  RAA   Wins  EFscore  \
# 0     1  RV Uthappa        Kolkata Knight Riders  285  0.968    0.210
# 1     2    MS Dhoni          Chennai Super Kings  229  0.779    0.143
# 2     3   DA Warner          Sunrisers Hyderabad  218  0.742    0.167
# 3     4  SL Malinga               Mumbai Indians  209  0.711    0.152
# 4     5    VR Aaron  Royal Challengers Bangalore  208  0.707    0.175
#
#        Salary       Value
# 0    $833,000  $1,696,711
# 1  $2,083,333  $1,466,583
# 2    $916,000  $1,421,532
# 3  $1,350,000  $1,383,786
# 4    $333,000  $1,378,916

# %% [markdown]
# ### Reading the IPL data of the year 2015

# %%
ipl_15=pd.read_csv("2015.csv")
ipl_15.head()
# Out:
#    Rank          Player                         Team  RAA   Wins  EFscore  \
# 0     1  AB de Villiers  Royal Challengers Bangalore  300  1.080    0.188
# 1     2       AM Rahane             Rajasthan Royals  274  0.986    0.180
# 2     3        DJ Bravo          Chennai Super Kings  251  0.901    0.227
# 3     4       DA Warner          Sunrisers Hyderabad  243  0.874    0.172
# 4     5    MC Henriques          Sunrisers Hyderabad  242  0.871    0.201
#
#        Salary       Value
# 0  $1,583,333  $1,689,095
# 1  $1,333,333  $1,585,393
# 2    $666,667  $1,491,620
# 3    $916,000  $1,461,833
# 4    $166,000  $1,458,524

# %% [markdown]
# ### Reading the IPL data of the year 2016

# %%
ipl_16=pd.read_csv("2016.csv")
ipl_16.head()
# Out:
#    Rank          Player                         Team  RAA   Wins  EFscore  \
# 0     1         V Kohli  Royal Challengers Bangalore  615  2.041    0.365
# 1     2       DA Warner          Sunrisers Hyderabad  414  1.375    0.237
# 2     3  AB de Villiers  Royal Challengers Bangalore  307  1.019    0.189
# 3     4       YS Chahal  Royal Challengers Bangalore  251  0.833    0.155
# 4     5       G Gambhir        Kolkata Knight Riders  241  0.799    0.147
#
#        Salary       Value
# 0  $2,500,000  $2,594,886
# 1    $916,000  $1,890,050
# 2  $1,583,333  $1,513,292
# 3     $16,000  $1,316,446
# 4  $1,666,667  $1,280,463

# %% [markdown]
# ### Reading the IPL data of the year 2017

# %%
ipl_17=pd.read_csv("2017.csv")
ipl_17.head()
# Out:
#    Rank      Player                     Team  RAA   Wins  EFscore    Salary  \
# 0     1   DA Warner      Sunrisers Hyderabad  351  1.274    0.211  $916,000
# 1     2  JD Unadkat  Rising Pune Supergiants  316  1.146    0.207   $45,000
# 2     3     B Kumar      Sunrisers Hyderabad  304  1.104    0.228  $708,000
# 3     4     HM Amla          Kings XI Punjab  236  0.854    0.151       NaN
# 4     5      AJ Tye            Gujarat Lions  205  0.742    0.132   $75,000
#
#         Value
# 0  $1,783,802
# 1  $1,648,517
# 2  $1,604,126
# 3  $1,339,898
# 4  $1,221,524

# %% [markdown]
# ### Reading the IPL data of the year 2018

# %%
ipl_18=pd.read_csv("2018.csv")
ipl_18.head()
# Out:
#    Rank         Player                 Team  RAA   Wins  EFscore      Salary  \
# 0     1  KS Williamson  Sunrisers Hyderabad  351  1.221    0.214    $468,750
# 1     2       KL Rahul      Kings XI Punjab  328  1.141    0.193  $1,718,750
# 2     3      AT Rayudu  Chennai Super Kings  327  1.137    0.198    $343,750
# 3     4        RR Pant     Delhi Daredevils  322  1.122    0.201  $2,343,750
# 4     5       MS Dhoni  Chennai Super Kings  290  1.011    0.167  $2,343,750
#
#         Value
# 0  $2,397,239
# 1  $2,280,549
# 2  $2,274,714
# 3  $2,252,835
# 4  $2,090,927

# %% [markdown]
# ### Reading the IPL data of the year 2019

# %%
ipl_19=pd.read_csv("2019.csv")
ipl_19.head()
# Out:
#    Rank       Player                   Team  RAA   Wins  EFscore      Salary  \
# 0     1    DA Warner    Sunrisers Hyderabad  410  1.414    0.224  $1,953,130
# 1     2   AD Russell  Kolkata Knight Riders  307  1.060    0.242  $1,328,130
# 2     3     MS Dhoni    Chennai Super Kings  305  1.053    0.176  $2,343,750
# 3     4  Imran Tahir    Chennai Super Kings  295  1.018    0.200    $156,250
# 4     5     KL Rahul        Kings XI Punjab  288  0.994    0.217  $1,718,750
#
#         Value
# 0  $2,742,662
# 1  $2,200,658
# 2  $2,189,940
# 3  $2,136,352
# 4  $2,099,606

# %% [markdown]
# ### Reading the IPL data of the year 2020

# %%
ipl_20=pd.read_csv("2020.csv")
ipl_20.head()
# Out:
#    Rank        Player             Team  RAA   Wins  EFscore      Salary  \
# 0     1     JJ Bumrah   Mumbai Indians  379  1.281    0.238  $1,093,750
# 1     2      KL Rahul  Kings XI Punjab  330  1.113    0.194  $1,718,750
# 2     3      K Rabada   Delhi Capitals  320  1.082    0.232    $656,250
# 3     4  Ishan Kishan   Mumbai Indians  261  0.881    0.157    $968,750
# 4     5      S Dhawan   Delhi Capitals  249  0.842    0.168    $812,500
#
#         Value
# 0  $2,448,655
# 1  $2,204,319
# 2  $2,159,233
# 3  $1,866,902
# 4  $1,810,181

# %% [markdown]
# ### Reading the IPL data of the year 2021

# %%
ipl_21=pd.read_csv("2021.csv")
ipl_21.head()
# Out:
#    Rank        Player                         Team  RAA   Wins  EFscore  \
# 0     1      KL Rahul                 Punjab Kings  222  0.783    0.248
# 1     2      HV Patel  Royal Challengers Bangalore  196  0.692    0.238
# 2     3      S Dhawan               Delhi Capitals  190  0.669    0.215
# 3     4  F du Plessis          Chennai Super Kings  184  0.649    0.177
# 4     5     CH Morris             Rajasthan Royals  159  0.560    0.219
#
#        Salary       Value
# 0  $1,718,750  $1,757,372
# 1     $31,250  $1,629,608
# 2    $812,500  $1,597,316
# 3    $250,000  $1,569,236
# 4  $2,321,400  $1,444,279

# %% [markdown]
# ### Concatinating the IPL data of all the years from teh year 2008 to 2021, and considering it the training data to predict the value of the player

# %%
ipl_full = pd.concat([ipl_08,ipl_09,ipl_10,ipl_11,ipl_12,ipl_13,ipl_14,ipl_15,ipl_16,ipl_17,ipl_18,ipl_19,ipl_20,ipl_21], ignore_index=True)

# %%
ipl_full
# Out:
#       Rank             Player                         Team  RAA   Wins  \
# 0        1           SE Marsh              Kings XI Punjab  377  1.355
# 1        2          SR Watson             Rajasthan Royals  347  1.250
# 2        3      Sohail Tanvir             Rajasthan Royals  294  1.059
# 3        4          G Gambhir             Delhi Daredevils  216  0.776
# 4        5           GC Smith             Rajasthan Royals  202  0.725
# ...    ...                ...                          ...  ...    ...
# 2290   127  Washington Sundar  Royal Challengers Bangalore -111 -0.391
# 2291   128           R Ashwin               Delhi Capitals -112 -0.394
# 2292   129          SN Thakur          Chennai Super Kings -114 -0.402
# 2293   130          SP Narine        Kolkata Knight Riders -126 -0.444
# 2294   131          R Tewatia             Rajasthan Royals -189 -0.667
#
#       EFscore      Salary       Value
# 0       0.231         NaN  $1,270,355
# 1       0.297    $125,000  $1,209,660
# 2       0.194         NaN  $1,099,252
# 3       0.160    $725,000    $935,664
# 4       0.139    $250,000    $906,183
# ...       ...         ...         ...
# 2290    0.054    $500,000    $109,075
# 2291    0.029  $1,100,000    $104,863
# 2292    0.066    $406,250     $93,631
# 2293    0.045  $1,953,130     $34,663
# 2294    0.059    $430,000   -$278,429
#
# [2295 rows x 8 columns]

# %% [markdown]
# ### Dropping the Rank column from the IPL data, since it doesn't contribute the target variable of preducting the IPL player value

# %%
ipl_full.drop(['Rank'],axis=1,inplace=True)

# %%
ipl_full
# Out:
#                  Player                         Team  RAA   Wins  EFscore  \
# 0              SE Marsh              Kings XI Punjab  377  1.355    0.231
# 1             SR Watson             Rajasthan Royals  347  1.250    0.297
# 2         Sohail Tanvir             Rajasthan Royals  294  1.059    0.194
# 3             G Gambhir             Delhi Daredevils  216  0.776    0.160
# 4              GC Smith             Rajasthan Royals  202  0.725    0.139
# ...                 ...                          ...  ...    ...      ...
# 2290  Washington Sundar  Royal Challengers Bangalore -111 -0.391    0.054
# 2291           R Ashwin               Delhi Capitals -112 -0.394    0.029
# 2292          SN Thakur          Chennai Super Kings -114 -0.402    0.066
# 2293          SP Narine        Kolkata Knight Riders -126 -0.444    0.045
# 2294          R Tewatia             Rajasthan Royals -189 -0.667    0.059
#
#           Salary       Value
# 0            NaN  $1,270,355
# 1       $125,000  $1,209,660
# 2            NaN  $1,099,252
# 3       $725,000    $935,664
# 4       $250,000    $906,183
# ...          ...         ...
# 2290    $500,000    $109,075
# 2291  $1,100,000    $104,863
# 2292    $406,250     $93,631
# 2293  $1,953,130     $34,663
# 2294    $430,000   -$278,429
#
# [2295 rows x 7 columns]

# %% [markdown]
# ### Checking the data types of all the features in the data

# %%
ipl_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2295 entries, 0 to 2294
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   2295 non-null   object
#  1   Team     2295 non-null   object
#  2   RAA      2295 non-null   int64
#  3   Wins     2295 non-null   float64
#  4   EFscore  2295 non-null   float64
#  5   Salary   1654 non-null   object
#  6   Value    2295 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 125.6+ KB

# %% [markdown]
# ### Checking for the duplicated values in the data and remove if any

# %%
ipl_full[ipl_full.duplicated(keep= False)]
# Out:
# Empty DataFrame
# Columns: [Player, Team, RAA, Wins, EFscore, Salary, Value]
# Index: []

# %% [markdown]
# ### Checking for the null values in all the features of the data

# %%
ipl_full.isna().sum()
# Out:
# Player       0
# Team         0
# RAA          0
# Wins         0
# EFscore      0
# Salary     641
# Value        0
# dtype: int64

# %% [markdown]
# ### Import Visualisation libraries

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### Visualize the player with higher frequency in all these years, in the form of Word Cloud. The bigger the size of the words, the more number of times, it has occured in the data

# %%
player = ipl_full.Player
player = player.dropna()
text = player.explode().to_list()
wc = WordCloud(width=1500, height=1000).generate(' '.join(text))
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wc)
plt.show()

# %% [markdown]
# ### Dropping the column Player and Team, since tehy do not add any value to the output player value

# %%
ipl_full=ipl_full.drop(["Player","Team"],axis=1)

# %% [markdown]
# ### Convert the salary column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Salary'] = ipl_full['Salary'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the value column to float data type, since it is an object with the strings and characters

# %%
ipl_full['Value'] = ipl_full['Value'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# ### Convert the RAA column to float data type

# %%
ipl_full["RAA"]=ipl_full["RAA"].astype(float)

# %%
ipl_full
# Out:
#         RAA   Wins  EFscore     Salary      Value
# 0     377.0  1.355    0.231        NaN  1270355.0
# 1     347.0  1.250    0.297   125000.0  1209660.0
# 2     294.0  1.059    0.194        NaN  1099252.0
# 3     216.0  0.776    0.160   725000.0   935664.0
# 4     202.0  0.725    0.139   250000.0   906183.0
# ...     ...    ...      ...        ...        ...
# 2290 -111.0 -0.391    0.054   500000.0   109075.0
# 2291 -112.0 -0.394    0.029  1100000.0   104863.0
# 2292 -114.0 -0.402    0.066   406250.0    93631.0
# 2293 -126.0 -0.444    0.045  1953130.0    34663.0
# 2294 -189.0 -0.667    0.059   430000.0  -278429.0
#
# [2295 rows x 5 columns]

# %% [markdown]
# ### Use seaborn  library for visualisation of the whether the data is normally distributed

# %%
import seaborn as sns

# %%
sns.pairplot(data=ipl_full)

# %% [markdown]
# ### Check the statistics of the data

# %%
ipl_full.describe()
# Out:
#                RAA         Wins      EFscore        Salary         Value
# count  2295.000000  2295.000000  2295.000000  1.654000e+03  2.295000e+03
# mean      0.016558     0.000053     0.058167  5.568884e+05  5.604768e+05
# std      92.440601     0.330368     0.052138  5.447984e+05  3.739169e+05
# min    -339.000000    -1.231000     0.000000  1.500000e+04 -8.798860e+05
# 25%     -52.000000    -0.188000     0.015000  1.500000e+05  3.723030e+05
# 50%     -14.000000    -0.051000     0.045000  4.000000e+05  5.130720e+05
# 75%      37.000000     0.134000     0.090000  7.500000e+05  6.876275e+05
# max     615.000000     2.041000     0.365000  3.000000e+06  2.742662e+06

# %% [markdown]
# ### Import Pycaret Library, that automatically fits teh data to different models and compares them based on many loss functions and accuracy

# %%
from pycaret.regression import *

# %% [markdown]
# ### Pass the data and target feature to the pycaret model and specify required features for tuning

# %%
reg = setup(data = ipl_full, 
            target = 'Value',
            normalize = True,
            session_id=123)
# Out:
# <style  type="text/css" >
# #T_1ca0c_row3_col1,#T_1ca0c_row27_col1,#T_1ca0c_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_1ca0c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ca0c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1ca0c_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1ca0c_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1ca0c_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_1ca0c_row1_col1" class="data row1 col1" >Value</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1ca0c_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_1ca0c_row2_col1" class="data row2 col1" >(2295, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1ca0c_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_1ca0c_row3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1ca0c_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_1ca0c_row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1ca0c_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_1ca0c_row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1ca0c_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_1ca0c_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1ca0c_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_1ca0c_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1ca0c_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_1ca0c_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_1ca0c_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_1ca0c_row9_col1" class="data row9 col1" >(1606, 3)</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_1ca0c_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_1ca0c_row10_col1" class="data row10 col1" >(689, 3)</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_1ca0c_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_1ca0c_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_1ca0c_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_1ca0c_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_1ca0c_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_1ca0c_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_1ca0c_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_1ca0c_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_1ca0c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_1ca0c_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_1ca0c_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_1ca0c_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_1ca0c_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_1ca0c_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_1ca0c_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_1ca0c_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_1ca0c_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_1ca0c_row19_col1" class="data row19 col1" >bf72</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_1ca0c_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_1ca0c_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_1ca0c_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_1ca0c_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_1ca0c_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_1ca0c_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_1ca0c_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_1ca0c_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_1ca0c_level0_row2

# %% [markdown]
# ### comparing the results of accuracy and loss functions of different models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_a4b03_ th {
#           text-align: left;
#     }#T_a4b03_row0_col0,#T_a4b03_row0_col5,#T_a4b03_row0_col6,#T_a4b03_row1_col0,#T_a4b03_row1_col1,#T_a4b03_row1_col2,#T_a4b03_row1_col3,#T_a4b03_row1_col4,#T_a4b03_row1_col5,#T_a4b03_row1_col6,#T_a4b03_row2_col0,#T_a4b03_row2_col1,#T_a4b03_row2_col2,#T_a4b03_row2_col3,#T_a4b03_row2_col4,#T_a4b03_row2_col5,#T_a4b03_row2_col6,#T_a4b03_row3_col0,#T_a4b03_row3_col1,#T_a4b03_row3_col2,#T_a4b03_row3_col3,#T_a4b03_row3_col4,#T_a4b03_row3_col5,#T_a4b03_row3_col6,#T_a4b03_row4_col0,#T_a4b03_row4_col1,#T_a4b03_row4_col2,#T_a4b03_row4_col3,#T_a4b03_row4_col4,#T_a4b03_row4_col5,#T_a4b03_row4_col6,#T_a4b03_row5_col0,#T_a4b03_row5_col1,#T_a4b03_row5_col2,#T_a4b03_row5_col3,#T_a4b03_row5_col4,#T_a4b03_row5_col5,#T_a4b03_row5_col6,#T_a4b03_row6_col0,#T_a4b03_row6_col1,#T_a4b03_row6_col2,#T_a4b03_row6_col3,#T_a4b03_row6_col4,#T_a4b03_row6_col5,#T_a4b03_row6_col6,#T_a4b03_row7_col0,#T_a4b03_row7_col1,#T_a4b03_row7_col2,#T_a4b03_row7_col3,#T_a4b03_row7_col4,#T_a4b03_row7_col5,#T_a4b03_row7_col6,#T_a4b03_row8_col0,#T_a4b03_row8_col1,#T_a4b03_row8_col2,#T_a4b03_row8_col3,#T_a4b03_row8_col4,#T_a4b03_row9_col0,#T_a4b03_row9_col1,#T_a4b03_row9_col2,#T_a4b03_row9_col3,#T_a4b03_row9_col4,#T_a4b03_row9_col5,#T_a4b03_row9_col6,#T_a4b03_row10_col0,#T_a4b03_row10_col1,#T_a4b03_row10_col2,#T_a4b03_row10_col3,#T_a4b03_row10_col4,#T_a4b03_row10_col5,#T_a4b03_row10_col6,#T_a4b03_row11_col0,#T_a4b03_row11_col1,#T_a4b03_row11_col2,#T_a4b03_row11_col3,#T_a4b03_row11_col4,#T_a4b03_row11_col5,#T_a4b03_row11_col6,#T_a4b03_row12_col0,#T_a4b03_row12_col1,#T_a4b03_row12_col2,#T_a4b03_row12_col3,#T_a4b03_row12_col4,#T_a4b03_row12_col5,#T_a4b03_row12_col6,#T_a4b03_row13_col0,#T_a4b03_row13_col1,#T_a4b03_row13_col2,#T_a4b03_row13_col3,#T_a4b03_row13_col4,#T_a4b03_row13_col5,#T_a4b03_row13_col6,#T_a4b03_row14_col0,#T_a4b03_row14_col1,#T_a4b03_row14_col2,#T_a4b03_row14_col3,#T_a4b03_row14_col4,#T_a4b03_row14_col5,#T_a4b03_row14_col6,#T_a4b03_row15_col0,#T_a4b03_row15_col1,#T_a4b03_row15_col2,#T_a4b03_row15_col3,#T_a4b03_row15_col4,#T_a4b03_row15_col5,#T_a4b03_row15_col6,#T_a4b03_row16_col0,#T_a4b03_row16_col1,#T_a4b03_row16_col2,#T_a4b03_row16_col3,#T_a4b03_row16_col4,#T_a4b03_row16_col5,#T_a4b03_row16_col6,#T_a4b03_row17_col0,#T_a4b03_row17_col1,#T_a4b03_row17_col2,#T_a4b03_row17_col3,#T_a4b03_row17_col4,#T_a4b03_row17_col5,#T_a4b03_row17_col6,#T_a4b03_row18_col0,#T_a4b03_row18_col1,#T_a4b03_row18_col2,#T_a4b03_row18_col3,#T_a4b03_row18_col4,#T_a4b03_row18_col5,#T_a4b03_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_a4b03_row0_col1,#T_a4b03_row0_col2,#T_a4b03_row0_col3,#T_a4b03_row0_col4,#T_a4b03_row8_col5,#T_a4b03_row8_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_a4b03_row0_col7,#T_a4b03_row1_col7,#T_a4b03_row2_col7,#T_a4b03_row3_col7,#T_a4b03_row5_col7,#T_a4b03_row6_col7,#T_a4b03_row7_col7,#T_a4b03_row8_col7,#T_a4b03_row9_col7,#T_a4b03_row10_col7,#T_a4b03_row11_col7,#T_a4b03_row12_col7,#T_a4b03_row13_col7,#T_a4b03_row14_col7,#T_a4b03_row15_col7,#T_a4b03_row16_col7,#T_a4b03_row17_col7,#T_a4b03_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_a4b03_row4_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_a4b03_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4b03_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_a4b03_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_a4b03_row0_col1" class="data row0 col1" >93529.5643</td>
#                         <td id="T_a4b03_row0_col2" class="data row0 col2" >16502462049.9662</td>
#                         <td id="T_a4b03_row0_col3" class="data row0 col3" >128158.1203</td>
#                         <td id="T_a4b03_row0_col4" class="data row0 col4" >0.8789</td>
#                         <td id="T_a4b03_row0_col5" class="data row0 col5" >0.4925</td>
#                         <td id="T_a4b03_row0_col6" class="data row0 col6" >0.4628</td>
#                         <td id="T_a4b03_row0_col7" class="data row0 col7" >0.6060</td>
#             </tr>
#             <tr>
#                         <th id="T_a4b03_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_a4b03_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_a4b03_row1_col1" class="data row1 col1" >95233.7382</td>
#                         <td id="T_a4b03_row1_col2" class="data row1 col2" >16652605643.2718</td>
#                         <td id="T_a4b03_row1_col3" class="data row1 col3" >128763.4027</td>
#                         <td id="T_a4b03_row1_col4" class="data row1 col4" >0.8774</td>
#                         <td id="T_a4b03_row1_col5" class="data row1 col5" >0.5544</td>
#                         <td id="T_a4b03_row1_col6" class="data row1 col6" >0.4677</td>
#                         <td id="T_a4b03_row1_col7" class="data row1 col7" >0.0790</td>
#             </tr>
#             <tr>
#                         <th id="T_a4b03_level0_row2" class="row_heading level0 row2" >lasso</th>
#                         <td id="T_a4b03_row2_col0" class="data row2 col0" >Lasso Regression</td>
#                         <td id="T_a4b03_row2_col1" class="data row2 col1" >101429.2359</td>
#                         <td id="T_a4b03_row2_col2" class="data row2 col2" >17419006668.8000</td>
#                         <td id="T_a4b03_row2_col3" class="data row2 col3" >131615.3344</td>
#                         <td id="T_a4b03_row2_col4" class="data row2 col4" >0.8724</td>
#                         <td id="T_a4b03_row2_col5" class="data row2 col5" >0.5619</td>
#                         <td id="T_a4b03_row2_col6" class="data row2 col6" >0.5254</td>
#                         <td id="T_a4b03_row2_col7" class="data row2 col7" >0.0150</td>
#             </tr>
#             <tr>
#                         <th id="T_a4b03_level0_row3" class="row_heading level0 row3" >ridge</th>
#                         <td id="T_a4b03_row3_col0" class="data row3 col0" >Ridge Regression</td>
#                         <td id="T_a4b03_row3_col1" class="data row3 col1" >101421.1172</td>
#                         <td id="T_a4b03_row3_col2" class="data row3 col2" >17419026739.2000</td>
#                         <td id="T_a4b03_row3_col3" class="data row3 col3" >131614.8312</td>
#                         <td id="T_a4b03_row3_col4" class="data row3 col4" >0.8724</td>
#                         <td id="T_a4b03_row3_col5" class="data row3 col5" >0.5621</td>
#                         <td id="T_a4b03_row3_col6" class="data row3 col6" >0.5261</td>
#                         <td id="T_a4b03_row3_col7" class="data row3 col7" >0.0120</td>
#             </tr>
#             <tr>
#                         <th id="T_a4b03_level0_row4" class="row_heading level0 row4" >lar</th>
#                         <td id="T_a4b03_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#                         <td id="T_a4b03_row4_col1" class="data row4 col1" >101429.2292</td>
#                         <td id="T_a4b03_row4_col2" class="data row4 col2" >17419009677.1956</td>
#                         <td id="T_a4b03_row4_col3" class="data row4 col3" >131615.3480</td>
#                         <

# %% [markdown]
# ### Create a variable to save the parameters considered for teh catboost regressor, since it has a relatively high accuracy and low RMSe value

# %%
catboost = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_f32c6_row10_col0,#T_f32c6_row10_col1,#T_f32c6_row10_col2,#T_f32c6_row10_col3,#T_f32c6_row10_col4,#T_f32c6_row10_col5{
#             background:  yellow;
#         }</style><table id="T_f32c6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f32c6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f32c6_row0_col0" class="data row0 col0" >100523.5275</td>
#                         <td id="T_f32c6_row0_col1" class="data row0 col1" >19996719893.3705</td>
#                         <td id="T_f32c6_row0_col2" class="data row0 col2" >141409.7588</td>
#                         <td id="T_f32c6_row0_col3" class="data row0 col3" >0.8838</td>
#                         <td id="T_f32c6_row0_col4" class="data row0 col4" >0.3760</td>
#                         <td id="T_f32c6_row0_col5" class="data row0 col5" >0.2502</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f32c6_row1_col0" class="data row1 col0" >100681.7715</td>
#                         <td id="T_f32c6_row1_col1" class="data row1 col1" >17503594271.3469</td>
#                         <td id="T_f32c6_row1_col2" class="data row1 col2" >132301.1499</td>
#                         <td id="T_f32c6_row1_col3" class="data row1 col3" >0.8854</td>
#                         <td id="T_f32c6_row1_col4" class="data row1 col4" >0.5322</td>
#                         <td id="T_f32c6_row1_col5" class="data row1 col5" >0.3352</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f32c6_row2_col0" class="data row2 col0" >84077.5090</td>
#                         <td id="T_f32c6_row2_col1" class="data row2 col1" >13609041971.3776</td>
#                         <td id="T_f32c6_row2_col2" class="data row2 col2" >116657.7986</td>
#                         <td id="T_f32c6_row2_col3" class="data row2 col3" >0.8280</td>
#                         <td id="T_f32c6_row2_col4" class="data row2 col4" >0.4731</td>
#                         <td id="T_f32c6_row2_col5" class="data row2 col5" >0.5105</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f32c6_row3_col0" class="data row3 col0" >86168.0826</td>
#                         <td id="T_f32c6_row3_col1" class="data row3 col1" >13998804459.5616</td>
#                         <td id="T_f32c6_row3_col2" class="data row3 col2" >118316.5435</td>
#                         <td id="T_f32c6_row3_col3" class="data row3 col3" >0.8781</td>
#                         <td id="T_f32c6_row3_col4" class="data row3 col4" >0.4218</td>
#                         <td id="T_f32c6_row3_col5" class="data row3 col5" >0.3066</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f32c6_row4_col0" class="data row4 col0" >97420.8641</td>
#                         <td id="T_f32c6_row4_col1" class="data row4 col1" >19681680731.7856</td>
#                         <td id="T_f32c6_row4_col2" class="data row4 col2" >140291.4136</td>
#                         <td id="T_f32c6_row4_col3" class="data row4 col3" >0.8884</td>
#                         <td id="T_f32c6_row4_col4" class="data row4 col4" >0.5356</td>
#                         <td id="T_f32c6_row4_col5" class="data row4 col5" >0.4174</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f32c6_row5_col0" class="data row5 col0" >88864.4642</td>
#                         <td id="T_f32c6_row5_col1" class="data row5 col1" >14223491680.3023</td>
#                         <td id="T_f32c6_row5_col2" class="data row5 col2" >119262.2810</td>
#                         <td id="T_f32c6_row5_col3" class="data row5 col3" >0.8722</td>
#                         <td id="T_f32c6_row5_col4" class="data row5 col4" >0.6060</td>
#                         <td id="T_f32c6_row5_col5" class="data row5 col5" >1.2486</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f32c6_row6_col0" class="data row6 col0" >92668.2165</td>
#                         <td id="T_f32c6_row6_col1" class="data row6 col1" >15577569676.4149</td>
#                         <td id="T_f32c6_row6_col2" class="data row6 col2" >124810.1345</td>
#                         <td id="T_f32c6_row6_col3" class="data row6 col3" >0.8998</td>
#                         <td id="T_f32c6_row6_col4" class="data row6 col4" >0.4262</td>
#                         <td id="T_f32c6_row6_col5" class="data row6 col5" >0.3175</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f32c6_row7_col0" class="data row7 col0" >89939.7791</td>
#                         <td id="T_f32c6_row7_col1" class="data row7 col1" >14607049548.2090</td>
#                         <td id="T_f32c6_row7_col2" class="data row7 col2" >120859.6275</td>
#                         <td id="T_f32c6_row7_col3" class="data row7 col3" >0.8933</td>
#                         <td id="T_f32c6_row7_col4" class="data row7 col4" >0.4289</td>
#                         <td id="T_f32c6_row7_col5" class="data row7 col5" >0.3569</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f32c6_row8_col0" class="data row8 col0" >99176.6549</td>
#                         <td id="T_f32c6_row8_col1" class="data row8 col1" >17620982066.7542</td>
#                         <td id="T_f32c6_row8_col2" class="data row8 col2" >132744.0472</td>
#                         <td id="T_f32c6_row8_col3" class="data row8 col3" >0.8877</td>
#                         <td id="T_f32c6_row8_col4" class="data row8 col4" >0.6207</td>
#                         <td id="T_f32c6_row8_col5" class="data row8 col5" >0.5466</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f32c6_row9_col0" class="data row9 col0" >95774.7738</td>
#                         <td id="T_f32c6_row9_col1" class="data row9 col1" >18205686200.5392</td>
#                         <td id="T_f32c6_row9_col2" class="data row9 col2" >134928.4484</td>
#                         <td id="T_f32c6_row9_col3" class="data row9 col3" >0.8722</td>
#                         <td id="T_f32c6_row9_col4" class="data row9 col4" >0.5046</td>
#                         <td id="T_f32c6_row9_col5" class="data row9 col5" >0.3385</td>
#             </tr>
#             <tr>
#                         <th id="T_f32c6_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_f32c6_row10_col0" class="data row10 col0" >93529.5643</td>
#                         <td id="T_f32c6_row10_col1" class="data row10 col1" >16502462049.9662</td>
#                         <td id="T_f32c6_row10_col2" class="data row10 col2" >128158.1203</td>
#                         <td id="T_f32c6_row10_col3" class="data row10 col3" >0.8789</td>
#                         <td id="T_f32c6_row10_col4" class="data row10 col4" >0.4925</td>
#                         <td id="T_f32c6_row10_col5" class="data row10 col5" >0.4628</td>
#             </tr>

# %% [markdown]
# ### Fetching the parameters of the catboost regressor

# %%
catboost.get_params()
# Out:
# {'loss_function': 'RMSE',
#  'border_count': 254,
#  'verbose': False,
#  'task_type': 'CPU',
#  'random_state': 123}

# %% [markdown]
# ### Hyper parameter tuning for the catboost regressor model

# %%
catboost_tune=tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_cd1a4_row10_col0,#T_cd1a4_row10_col1,#T_cd1a4_row10_col2,#T_cd1a4_row10_col3,#T_cd1a4_row10_col4,#T_cd1a4_row10_col5{
#             background:  yellow;
#         }</style><table id="T_cd1a4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd1a4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cd1a4_row0_col0" class="data row0 col0" >105121.7355</td>
#                         <td id="T_cd1a4_row0_col1" class="data row0 col1" >21045212169.7276</td>
#                         <td id="T_cd1a4_row0_col2" class="data row0 col2" >145069.6804</td>
#                         <td id="T_cd1a4_row0_col3" class="data row0 col3" >0.8777</td>
#                         <td id="T_cd1a4_row0_col4" class="data row0 col4" >0.5858</td>
#                         <td id="T_cd1a4_row0_col5" class="data row0 col5" >0.2537</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cd1a4_row1_col0" class="data row1 col0" >97513.2659</td>
#                         <td id="T_cd1a4_row1_col1" class="data row1 col1" >15010892417.7235</td>
#                         <td id="T_cd1a4_row1_col2" class="data row1 col2" >122518.9472</td>
#                         <td id="T_cd1a4_row1_col3" class="data row1 col3" >0.9017</td>
#                         <td id="T_cd1a4_row1_col4" class="data row1 col4" >0.4974</td>
#                         <td id="T_cd1a4_row1_col5" class="data row1 col5" >0.3492</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cd1a4_row2_col0" class="data row2 col0" >85371.0562</td>
#                         <td id="T_cd1a4_row2_col1" class="data row2 col1" >13544979396.7739</td>
#                         <td id="T_cd1a4_row2_col2" class="data row2 col2" >116382.8999</td>
#                         <td id="T_cd1a4_row2_col3" class="data row2 col3" >0.8288</td>
#                         <td id="T_cd1a4_row2_col4" class="data row2 col4" >0.4524</td>
#                         <td id="T_cd1a4_row2_col5" class="data row2 col5" >0.6032</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cd1a4_row3_col0" class="data row3 col0" >94183.3575</td>
#                         <td id="T_cd1a4_row3_col1" class="data row3 col1" >15684874218.7833</td>
#                         <td id="T_cd1a4_row3_col2" class="data row3 col2" >125239.2679</td>
#                         <td id="T_cd1a4_row3_col3" class="data row3 col3" >0.8634</td>
#                         <td id="T_cd1a4_row3_col4" class="data row3 col4" >0.6458</td>
#                         <td id="T_cd1a4_row3_col5" class="data row3 col5" >0.3359</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cd1a4_row4_col0" class="data row4 col0" >103025.4820</td>
#                         <td id="T_cd1a4_row4_col1" class="data row4 col1" >21266245138.5350</td>
#                         <td id="T_cd1a4_row4_col2" class="data row4 col2" >145829.5071</td>
#                         <td id="T_cd1a4_row4_col3" class="data row4 col3" >0.8794</td>
#                         <td id="T_cd1a4_row4_col4" class="data row4 col4" >0.4602</td>
#                         <td id="T_cd1a4_row4_col5" class="data row4 col5" >0.4495</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cd1a4_row5_col0" class="data row5 col0" >88692.9245</td>
#                         <td id="T_cd1a4_row5_col1" class="data row5 col1" >12860473231.0013</td>
#                         <td id="T_cd1a4_row5_col2" class="data row5 col2" >113404.0265</td>
#                         <td id="T_cd1a4_row5_col3" class="data row5 col3" >0.8845</td>
#                         <td id="T_cd1a4_row5_col4" class="data row5 col4" >0.6579</td>
#                         <td id="T_cd1a4_row5_col5" class="data row5 col5" >1.2924</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cd1a4_row6_col0" class="data row6 col0" >93394.7173</td>
#                         <td id="T_cd1a4_row6_col1" class="data row6 col1" >15292462886.1813</td>
#                         <td id="T_cd1a4_row6_col2" class="data row6 col2" >123662.6980</td>
#                         <td id="T_cd1a4_row6_col3" class="data row6 col3" >0.9017</td>
#                         <td id="T_cd1a4_row6_col4" class="data row6 col4" >0.4113</td>
#                         <td id="T_cd1a4_row6_col5" class="data row6 col5" >0.3404</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cd1a4_row7_col0" class="data row7 col0" >93326.6327</td>
#                         <td id="T_cd1a4_row7_col1" class="data row7 col1" >14249815970.5379</td>
#                         <td id="T_cd1a4_row7_col2" class="data row7 col2" >119372.5930</td>
#                         <td id="T_cd1a4_row7_col3" class="data row7 col3" >0.8959</td>
#                         <td id="T_cd1a4_row7_col4" class="data row7 col4" >0.4060</td>
#                         <td id="T_cd1a4_row7_col5" class="data row7 col5" >0.3684</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cd1a4_row8_col0" class="data row8 col0" >98537.1008</td>
#                         <td id="T_cd1a4_row8_col1" class="data row8 col1" >16353456742.6633</td>
#                         <td id="T_cd1a4_row8_col2" class="data row8 col2" >127880.6347</td>
#                         <td id="T_cd1a4_row8_col3" class="data row8 col3" >0.8958</td>
#                         <td id="T_cd1a4_row8_col4" class="data row8 col4" >0.5997</td>
#                         <td id="T_cd1a4_row8_col5" class="data row8 col5" >0.5203</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cd1a4_row9_col0" class="data row9 col0" >98548.1007</td>
#                         <td id="T_cd1a4_row9_col1" class="data row9 col1" >19245452127.4046</td>
#                         <td id="T_cd1a4_row9_col2" class="data row9 col2" >138727.9789</td>
#                         <td id="T_cd1a4_row9_col3" class="data row9 col3" >0.8649</td>
#                         <td id="T_cd1a4_row9_col4" class="data row9 col4" >0.5350</td>
#                         <td id="T_cd1a4_row9_col5" class="data row9 col5" >0.4204</td>
#             </tr>
#             <tr>
#                         <th id="T_cd1a4_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_cd1a4_row10_col0" class="data row10 col0" >95771.4373</td>
#                         <td id="T_cd1a4_row10_col1" class="data row10 col1" >16455386429.9332</td>
#                         <td id="T_cd1a4_row10_col2" class="data row10 col2" >127808.8234</td>
#                         <td id="T_cd1a4_row10_col3" class="data row10 col3" >0.8794</td>
#                         <td id="T_cd1a4_row10_col4" class="data row10 col4" >0.5252</td>
#                         <td id="T_cd1a4_row10_col5" class="data row10 col5" >0.4933</td>
#             </tr>

# %%
print(catboost_tune)
# Out:
# <catboost.core.CatBoostRegressor object at 0x1314e3c70>

# %% [markdown]
# ### Evaluating the cat boost model

# %%
evaluate_model(catboost_tune)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Use the model to predict the IPL Player value and check the error values

# %%
predict_model(catboost_tune);
# Out:
# <style  type="text/css" >
# </style><table id="T_b1a10_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1a10_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b1a10_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_b1a10_row0_col1" class="data row0 col1" >89667.2289</td>
#                         <td id="T_b1a10_row0_col2" class="data row0 col2" >14249279344.2242</td>
#                         <td id="T_b1a10_row0_col3" class="data row0 col3" >119370.3453</td>
#                         <td id="T_b1a10_row0_col4" class="data row0 col4" >0.8958</td>
#                         <td id="T_b1a10_row0_col5" class="data row0 col5" >0.5008</td>
#                         <td id="T_b1a10_row0_col6" class="data row0 col6" >0.5680</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Finalise the catboost model

# %%
final_catboost = finalize_model(catboost_tune)

# %% [markdown]
# ### Importing the pickle file, in order to use it during deployment of the model

# %%
import pickle

# %% [markdown]
# ### Dump the created final cat boost mmodel to the pickle file

# %%
pickle.dump(final_catboost,open('ipl.pkl','wb'))
